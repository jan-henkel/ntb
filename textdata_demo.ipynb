# %% [markdown]
# <h1>Text data demo</h1>
# This notebook implements an lstm network trained character by character on an input text (much like Andrej Karpathy's char-rnn).

# %%
from ntb.datasets import textdata
import ntb
import matplotlib.pyplot as pp
import numpy as np

# %matplotlib inline

# %%
seq_length = 30
text_data,encode,decode = textdata.load("us_constitution.txt",seq_length=seq_length,stride=10)
num_train = len(text_data['X_train'])

# %%
vocab_length = len(text_data['charmap'])
embedding_dim = 32
hidden_dim = 64
batch_size = 25

mask_ones = np.ones([batch_size,seq_length])/seq_length
graph = ntb.ComputationGraph()

with ntb.default_graph(graph):
    x = ntb.Placeholder(shape=[-1,-1])
    y = ntb.Placeholder(shape=[-1,-1])
    lr = ntb.Placeholder()
    mask = ntb.Placeholder(shape=[-1,-1])
    sample_temperature = ntb.Placeholder()
    
    W_embed = ntb.Variable(initializer=ntb.xavier_init(shape=(vocab_length,embedding_dim)))
    x_emb = ntb.Embed(x,W_embed)
    
    lstm_1 = ntb.Lstm(num_units=hidden_dim)
    init_state_1 = lstm_1.get_zero_state(batch_size,as_node=True)
    h1,out_state_1 = lstm_1(x_emb,init_state_1)
    
    lstm_2 = ntb.Lstm(num_units=hidden_dim)
    init_state_2 = lstm_2.get_zero_state(batch_size,as_node=True)
    h2,out_state_2 = lstm_2(h1,init_state_2)
    
    Wscores = ntb.Variable(shape=[hidden_dim,vocab_length])
    bscores = ntb.Variable(value=np.zeros(vocab_length))
    scores = ntb.TemporalAffine(h2,Wscores,bscores)
    loss = ntb.TemporalCE(scores,y,mask)
    
    sample_prob = ntb.Softmax(scores/sample_temperature)
    sample = ntb.Sample(sample_prob)
    
    optim = ntb.Optim(loss_node=loss,lr=lr,update_rule='adam')

# %%
def get_batch():
    idx = np.random.choice(num_train,batch_size)
    return text_data['X_train'][idx],text_data['y_train'][idx]

def print_sample(length,temp=1,prime_text=" "):
    sample_out = []
    prime_text_seq = encode(prime_text).reshape(1,-1)
    state_1,state_2 = lstm_1.get_zero_state(1),lstm_2.get_zero_state(1)
    state_1,state_2,smp = graph.run([out_state_1,out_state_2,sample],
                                    assign_dict={x:prime_text_seq,
                                                 init_state_1:state_1,
                                                 init_state_2:state_2,
                                                 sample_temperature:temp})
    smp = smp[:,-1:]
    sample_out.append(smp[0,0])
    for i in range(length):
        state_1,state_2,smp = graph.run([out_state_1,out_state_2,sample],
                                        assign_dict={x:smp,init_state_1:state_1,
                                                     init_state_2:state_2,
                                                     sample_temperature:temp})
        sample_out.append(smp[0,0])
    sample_out = decode(np.array(sample_out))
    print(sample_out)

# %%
num_iterations = 15000
print_every = 1000
def train(num_iterations=num_iterations,print_every=print_every,learning_rate=3e-4):
    cumuloss_tr = 0
    for i in range(num_iterations+1):
        X,Y = get_batch()
        loss_tr,_ = graph.run([loss,optim],assign_dict={x:X,y:Y,lr:learning_rate,mask:mask_ones})
        cumuloss_tr+=loss_tr
        if i == 0:
            cumuloss_tr*=print_every
        if i % print_every == 0:
            print("Train loss:",cumuloss_tr/print_every,"\n")
            print("Sample:\n----------------------------------------")
            print_sample(200,prime_text=" ",temp=.7)
            print("----------------------------------------\n")
            cumuloss_tr = 0

# %%
train()
# Out:
# Loss: 4.33766992884
#
# Sample:
# ----------------------------------------
# gWtxwVuWW7fD)HRyHFzlIIf,7gO)WAzmWHBWJyVHnd51IUW;aD9RgmG08i7:DEkRq,ML ynK(B;:Ub2K5W
# 5Kq3dDE.qkSnOt1BW4Jgdmx
# WQFmulQD4"PYb9S"(2DqMH6ldu:,(nSO;P33QN;bdy))Py3H,ByBdN5llWGDG(3bJEqFcQDDne)YV(yFjc)f.Q)foj))J4
# ----------------------------------------
#
# Loss: 3.03453152001
#
# Sample:
# ----------------------------------------
# edt Thl an .arsif usacslhan the of be tevy the of on the  on un fhe leceteift SarLo qed als ucer e, gol ofnanes or teat ord ubes onotinf ters on an an atiby  ens Thavhe itase Pos the af te fhans otecte
# ----------------------------------------
#
# Loss: 2.31354856243
#
# Sample:
# ----------------------------------------
# on he erectatont; and be
# the Erent the te beerss the so the the cocege on ole and
# of there Erece sos innt voor thal of he pontenr of the Ceureseses of the in on thall fofent of Reint be Are the PunonSs
# ----------------------------------------
#
# Loss: 2.01018536052
#
# Sample:
# ----------------------------------------
# of Vation thal hich be ind of the State sherel
# who shall hall of themen Cerent of thall the Unates of the States, on the Sestes that other rece or the and the Unice satith Hition of the
# Proides ind and
# ----------------------------------------
#
# Loss: 1.81885855434
#
# Sample:
# ----------------------------------------
# of the lorse and rill in Pepreses tho miche to the Leasg.
#
# A.
# A
# NMendor of the Urectent of the Unition as at the of the ferall as the State shall be sect ay be the State Allate fave exthol ans of amlac
# ----------------------------------------
#
# Loss: 1.69802217704
#
# Sample:
# ----------------------------------------
# as the Unites of their and the shall have the United of the sigh Lant of the Vate shall and shall be persident the suche of the Vose, the electico of the Exiges the Recors of the Sine hay and of the Am
# ----------------------------------------
#
# Loss: 1.59541084078
#
# Sample:
# ----------------------------------------
# Constess and Law be be by be cidicites in Reeran a two the sich Cake and President and of the
# United States the United States, and President and cuving presins varved of the President, and not in of at
# ----------------------------------------
#
# Loss: 1.51586919385
#
# Sample:
# ----------------------------------------
# the sumerce of the State of a States of it vicitation Law the Untion of the Congress of
# the State shall be such Votes, and thit Statess and Buching the President of the Negresident and amportation, who
# ----------------------------------------
#
# Loss: 1.45220048331
#
# Sample:
# ----------------------------------------
# of Consess of the sigh and such Person and in the United State shall be the United Statess, and Resent the Votes shall be deish the Congress in elestatives shall be choriatitution or any State, be an t
# ----------------------------------------
#
# Loss: 1.39566104924
#
# Sample:
# ----------------------------------------
# ,hen malithans of the United States to the Constitutution in any States shall be then covoss
# wherel the
# Seate of the President, the president.
#
# Amendment of the Constitution as the person or deerators
# ----------------------------------------
#
# Loss: 1.34635688611
#
# Sample:
# ----------------------------------------
# of the Congressat of the States the Representated of the Senate shall have parsy by be proasing he quupes, and agaentary and dich Cases shall have Trive, or eigh a President shall have been President,
# ----------------------------------------
#
# Loss: 1.30231125167
#
# Sample:
# ----------------------------------------
# shall have power for the United States or and with have any State shall
# have constitution from Congress, in the hats of the United States shall be prosed to the States shall be Law by the Senate shall
# ----------------------------------------
#
# Loss: 1.2604843954
#
# Sample:
# ----------------------------------------
# time for the President the Constitution of the President and such Part shall be precent of the United States, and as of the United States;
#
# To coverstion may convided, be a President of the
# Enforse the
# ----------------------------------------
#
# Loss: 1.22736261903
#
# Sample:
# ----------------------------------------
# the Age of the Viscorts shall be propessing the to this the United States, choose the Congress in the seven States shall have been greatives and to the State viles of the House of President and eight o
# ----------------------------------------
#
# Loss: 1.19348569137
#
# Sample:
# ----------------------------------------
# the Consention of the Senate shall be lavion to the Congress shall not be hight to the same President of the United States shall be gile the President of the Contrion Rutlent shall be a presented the H
# ----------------------------------------
#
# Loss: 1.16840997363
#
# Sample:
# ----------------------------------------
# to enter or all Consent of the Seventors against the Explission of the President, and of the memong the same Tressing
# the President, and this right of the Constitution, in he shall be convented, and nu
# ----------------------------------------

# %%
train()
# Out:
# Loss: 1.23290025043
#
# Sample:
# ----------------------------------------
# the President of the
# United States, the Torom of the United States, other such Senator of Senators, of the United States, in one for the Senates shall have such Part, and all the Congress shall have be
# ----------------------------------------
#
# Loss: 1.13735143121
#
# Sample:
# ----------------------------------------
# the Legislature at the cimes shall exceed to the United States
# shall be present.
#
# Amendment 10
# Whe President of the same other State; he shall recessed yithort the Congress shall not be decurmed of the
# ----------------------------------------
#
# Loss: 1.1092698446
#
# Sample:
# ----------------------------------------
# temy shall be a Members for the Congress shall shall be proose the sight, with the State of the United States.
#
# Evengerions by Law be appointed to any person have devolveed in the Vice Pother constitut
# ----------------------------------------
#
# Loss: 1.08937795578
#
# Sample:
# ----------------------------------------
# any Presase in enteristion or Senators, and
# shall have dilitate. The Congress
# infore as the concurs; Article bil thereof the
# Law.
#
# 2. Thin respeptive ratified in the purpose thereof, shall have been to
# ----------------------------------------
#
# Loss: 1.06695225075
#
# Sample:
# ----------------------------------------
# of the Person
# shall not be or
# or bat Manner any State, or in the majority of the United States.
#
# The Congress may by Law in to a State unles of Treason, law.
#
# The President; and with the United States
# ----------------------------------------
#
# Loss: 1.04913856174
#
# Sample:
# ----------------------------------------
# the Ady of the person shall be a members of the President, the States by the President, be any State what he may; or any State shall be eighome the United States, which shall have power to the United S
# ----------------------------------------
#
# Loss: 1.02780489927
#
# Sample:
# ----------------------------------------
# Casest of the United States, shall be proromed by the United States, or act as a majority of the Constitution for the Congress may by law be a State shall be made for the Legislatures of the United Sta
# ----------------------------------------
#
# Loss: 1.00774297244
#
# Sample:
# ----------------------------------------
# other Consuls;
#
# To provided for President shall have disave conntion of the Representatives shall be denied the first House of the Senate shall in enters and or Affering the person against the Congress
# ----------------------------------------
#
# Loss: 0.989516459361
#
# Sample:
# ----------------------------------------
# and in Consent of the United
# States, which shall be cosate legislation, declare the
# Persons voted by the recessed by the Congress shall have one to any State whou limiting Grames of the United States s
# ----------------------------------------
#
# Loss: 0.974289255376
#
# Sample:
# ----------------------------------------
# this Constitution which a Case of the Constitution of the United States, or of profere, they shall be eligiane thereof Years, and for the States by the Gaves, or of the United States shall be prorosed
# ----------------------------------------
#
# Loss: 0.953561986788
#
# Sample:
# ----------------------------------------
# term of his article, or other States, and of the president shall have been Congress.
#
# 3. The Senates shall be proved by the remeot or the same of the Executive thereof the to the same of the Senate and
# ----------------------------------------
#
# Loss: 0.938860591886
#
# Sample:
# ----------------------------------------
# and eightures of the remove may if no Amposting
# thereof, to the States by the United States of within, shall be elected to any person having the greatest of the Congress may by acthabling the Congress
# ----------------------------------------
#
# Loss: 0.928954578026
#
# Sample:
# ----------------------------------------
# the Congress and
# udjuid of the United States shall be
# law.
#
# 2. The Senate be forting such Prosecorsy one of the executive for the Congress shall have been ratified and such conned
# of the United States,
# ----------------------------------------
#
# Loss: 0.915551807939
#
# Sample:
# ----------------------------------------
# the Senate shall have been case or importion or enumeration be the time of the United States, and with fach made in and party and Consuls, and excisol, Gublic Font of the United States shall be seven y
# ----------------------------------------
#
# Loss: 0.903129224131
#
# Sample:
# ----------------------------------------
# the Member of choice shall be inoperative for the same of the State legislation, and as President, and of the people
# the Congress may by Law any Number of the United States, and of the Union,
# which may
# ----------------------------------------
#
# Loss: 0.886300746132
#
# Sample:
# ----------------------------------------
# the Congress shall, beton of Service of Congress, or of hinner to
# is which such State, except, as subject the same such Meashary
# Years, and a majority of the submission vote, the United States, shall b
# ----------------------------------------

# %%
#let's generate a longer sample and prime the RNN with "The se"

print_sample(length=1000,prime_text="The se",temp=.5)
# Out:
# veral States shall be appointed by all such Senators and Representatives shall have been a President or Importation thereof, institution of the United States, and post the United States, and such Bills of the suple States, and with he shall not act all State in the President of the such House of Representatives in the several States, and the several States shall be presence of the United States, without the Consent of the United States; and in a majority of the United States, shall be made on the United States or of his a President of the Congress may by Law appoint and person shall be appropriate legislation.
#
# Amendment 11
# The executive thereof the two-thirds of the United States of account of the United States, and be entitled to all grants of the United States or Tribe, and a Manner shall be a Representatives, shall be appointed to any such Measess oncess of the Senate and House of Males of the United States, and which such Consist of the President or Citizens of the United States, a

# %%
import pickle

# %%
#run this to save the current model
with open('textdata_model.pickle','wb') as f:
    pickle.dump(graph.save(),f)

# %%
#run this to load the saved model
with open('textdata_model.pickle','rb') as f:
    graph.load(pickle.load(f))
